# %% [markdown]
# # Model Analysis Notebook

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
npy_root_path = '../data/npy'

# %%
y_pred_lin = np.load(f'{npy_root_path}/y_pred_lin.npy')
y_true_lin = np.load(f'{npy_root_path}/y_test_lin.npy')

y_pred_mlp = np.load(f'{npy_root_path}/y_pred_mlp.npy')
y_true_mlp = np.load(f'{npy_root_path}/y_test_mlp.npy')

y_pred_cnn = np.load(f'{npy_root_path}/y_pred_cnn.npy')
y_true_cnn = np.load(f'{npy_root_path}/y_test_cnn.npy')

y_pred = np.load(f'{npy_root_path}/y_pred.npy')
y_true = np.load(f'{npy_root_path}/y_test.npy')

# %% [markdown]
# linear model

# %%
date_range = pd.date_range(start='2017-01-01', end='2018-12-31', periods=len(y_true))

plt.figure(figsize=(10, 6))
plt.plot(date_range, y_pred_lin, label='Predictions', color='red', linestyle='-')
plt.plot(date_range, y_true_lin, label='Ground Truth', color='blue')
plt.xlabel('time', fontsize=36)
plt.ylabel('wave height (m)', fontsize=36)
plt.title('linear regression', fontsize=36)
# plt.legend(fontsize=18)

plt.ylim([-5, 5])

plt.show()

# %% [markdown]
# analyzing mlp

# %%
date_range = pd.date_range(start='2017-01-01', end='2018-12-31', periods=len(y_true))

plt.figure(figsize=(10, 6))
plt.plot(date_range, y_pred_mlp, label='Predictions', color='red', linestyle='-')
plt.plot(date_range, y_true_mlp, label='Ground Truth', color='blue')
plt.xlabel('time', fontsize=36)
plt.ylabel('wave height (m)', fontsize=36)
plt.title('multi-layer perceptron', fontsize=36)
plt.legend(fontsize=18)
plt.ylim([0, 5])

plt.show()

# %% [markdown]
# analyze CNN predictions against actual

# %%
date_range = pd.date_range(start='2017-01-01', end='2018-12-31', periods=len(y_true))

plt.figure(figsize=(10, 6))
plt.plot(date_range, y_true_cnn, label='Ground Truth', color='blue')
plt.plot(date_range, y_pred_cnn, label='Predictions', color='red', linestyle='-')
plt.xlabel('time', fontsize=18)
plt.ylabel('wave height (m)', fontsize=18)
plt.title('convolutional neural network', fontsize=18)
plt.legend(fontsize=18)

plt.show()

# %%
y_pred_lin = y_pred_lin.squeeze()
residuals_lin = y_true_lin - y_pred_lin

y_pred_cnn = y_pred_cnn.squeeze()
residuals = y_true_cnn - y_pred_cnn

# %%
y_pred_mlp = y_pred_mlp.squeeze()
residuals_mlp = y_true_mlp - y_pred_mlp

# %%
# Plot residuals over time
date_range = pd.date_range(start='2022-01-01', end='2022-12-31', periods=len(y_true))

plt.figure(figsize=(10, 6))
plt.scatter(y_pred_lin, residuals_lin, color='blue', edgecolors='black')
plt.axhline(0, color='red', linestyle='--')
plt.title('Residuals vs Fitted Values (Linear Regression)')
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.show()

# %%
# Plot residuals over time
date_range = pd.date_range(start='2022-01-01', end='2022-12-31', periods=len(y_true))

plt.figure(figsize=(10, 6))
plt.scatter(y_pred_cnn, residuals, color='blue', edgecolors='black')
plt.axhline(0, color='red', linestyle='--')
plt.title('Residuals vs Fitted Values (Linear Regression)')
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.show()

# %% [markdown]
# comparing data from 2016 vs 2018 predicting on 2022

# %%
y_pred_2016 = np.load(f'{npy_root_path}/y_pred_cnn2016.npy')
y_true_2016 = np.load(f'{npy_root_path}/y_test_cnn2016.npy')

y_pred_2018 = np.load(f'{npy_root_path}/y_pred_cnn2018.npy')
y_true_2018 = np.load(f'{npy_root_path}/y_test_cnn2018.npy')

y_pred_201678 = np.load(f'{npy_root_path}/y_pred_cnn201678.npy')
y_true_201678 = np.load(f'{npy_root_path}/y_test_cnn201678.npy')

# %%
date_range = pd.date_range(start='2022-01-01', end='2022-12-31', periods=len(y_true))

plt.figure(figsize=(10, 6))
plt.plot(date_range, y_true_2016, label='Ground Truth', color='blue')
plt.plot(date_range, y_pred_2016, label='Predictions', color='red', linestyle='-')
plt.xlabel('time', fontsize=18)
plt.ylabel('wave height (m)', fontsize=18)
plt.title('Train on 2016, Predict on 2022 (CNN)', fontsize=18)
plt.legend(fontsize=18)

plt.show()

# %%
date_range = pd.date_range(start='2022-01-01', end='2022-12-31', periods=len(y_true))

plt.figure(figsize=(10, 6))
plt.plot(date_range, y_true, label='Ground Truth', color='blue')
plt.plot(date_range, y_pred, label='Predictions', color='red', linestyle='-')
plt.xlabel('time', fontsize=18)
plt.ylabel('wave height (m)', fontsize=18)
plt.title('Train on 2017, Predict on 2022 (CNN)', fontsize=18)
plt.legend(fontsize=18)

plt.show()

# %%
date_range = pd.date_range(start='2022-01-01', end='2022-12-31', periods=len(y_true))

plt.figure(figsize=(10, 6))
plt.plot(date_range, y_true_2018, label='Ground Truth', color='blue')
plt.plot(date_range, y_pred_2018, label='Predictions', color='red', linestyle='-')
plt.xlabel('time', fontsize=18)
plt.ylabel('wave height (m)', fontsize=18)
plt.title('Train on 2018, Predict on 2022 (CNN)', fontsize=18)
plt.legend(fontsize=18)

plt.show()

# %%
date_range = pd.date_range(start='2022-01-01', end='2022-12-31', periods=len(y_true))

plt.figure(figsize=(10, 6))
plt.plot(date_range, y_true_201678, label='Ground Truth', color='blue')
plt.plot(date_range, y_pred_201678, label='Predictions', color='red', linestyle='-')
plt.xlabel('time', fontsize=18)
plt.ylabel('wave height (m)', fontsize=18)
plt.title('Train on 2016, 2017, and 2018, Predict on 2022 (CNN)', fontsize=18)
plt.legend(fontsize=18)

plt.show()
